# %% [markdown]
# # Minería de datos
# ##  Avance del Producto Integrador de Aprendizaje
# ### Base a trabajar: Autos - Consumo Gasolina México
# #### URL: https://www.kaggle.com/checoalejandro/autos-consumo-gasolina-mexico
#
# #### Integrantes del Equipo 10, grupo 003:
# - Andrea Isabel Cortez Sánchez 1736472
# - Sergio Oviedo Martínez 1750532
# - Andrés Hernandez de Luna 1757180
# - Johan Antonio Sustaita Martinez 1723476

# %%
#Mandamos llamar a nuestra base de datos
import pandas as pd
import numpy as np 
data = pd.read_excel("C:/Users/telmex/Documents/Consumo Gasolina Autos Ene 2018.xlsx")

# %% [markdown]
# #### Tipo de Datos:
#
# Datos relacionados con la marca, submarca, modelo, características del motor y consumos en ciudad, carretera y promedio. Así como también, calificación de sus emisiones de gas.
#
#
# - Columna 1 'Marca': En esta podemos ver las diferentes marcas de vehículos.
# - Columna 2 'Submarca': Se muestra el nombre del vehículo.
# - Columna 3 'Versión': Estilo del carro.
# - Columna 4 'Modelo': Año de lanzamiento del vehículo.
# - Columna 5 'Trans': Tipo de transmisión
# - Columna 6 'Comb.': Tipo de combustible
# - Columna 7 'Cilindros': Cantidad de cilindros.
# - Columna 8 'Potencia': Potencia
# - Columna 9 'Tamaño': Tamaño del motor.
# - Columna 10 'Categoría': Categoría a la que pertenece (autos de lujo, deportivo, convencional, etc)
# - Columna 11 'R. Ciudad (km/l)': Rendimiento en Ciudad
# - Columna 12 'R. Carr. (km/l)': Rendimiento en carrretera
# - Columna 13 'R. Comb (km/l)': Rendimiento de combustible
# - Columna 14 'R. Ajust (km/l)': Rendimiento ajustable
# - Columna 15 'CO2 (g/km)': Emisiones de CO2
# - Columna 16 'NOx (g/1000km)': Emisiones de NOx
# - Columna 17 'Calificación Gas Ef. Inv.': Calificación del vehículo
# - Columna 18 'Calificación Contam. Aire': Calificación de que tanto contamina
#
# #### Justificación del uso de datos
#
# La potencia que vimos como equipo en esta base de datos fue poder comparar las diferentes marcas de vehículos que existen hoy en día en el mercado para poder hacer recomendación fundamentada en datos reales al momento de querer alguien comprar un carro. Algo que nos preocupa mucho como sociedad es la calidad de aire que respiramos así como el medio ambiente, es por eso que esta es la base ideal que nos ayuda diciendo cuál es aquel que contamina más.
#
# #### Objetivo:
#
# Nuestro objetivo es saber 100% la manipulación de los datos pero ir de la mano con el aprendizaje de los temas a tratar.
#
# #### Preguntas de interés:
#
# - ¿Cuál es la submarca de cada marca que contamina más?
# - El vehículo con mejor rendimiento en carretera.
# - Marca con calificación positiva en gas efecto invernadero
# - ¿Qué categoría tiene un mejor rendimiento en ciudad pero contamina más?
# - ¿Qué categoría tiene un mejor rendimiento de combustible y contamina menos?

# %%
#Vemos los primeros 5 datos de nuestras 18 columnas
data.head()
# Out:
#   Marca Submarca                                        Versión  Modelo  \
# 0  FORD   FUSION         HIBRIDO 4PTS 2.0L 4CIL 188HP AUT (CVT)    2015
# 1  FORD   FUSION        HIBRIDO 4PTS 2.0L 4CIL 188HP AUT (eCVT)    2016
# 2  FORD   FUSION  HIBRIDO 4X2 4PTAS 2.0L 4CIL 141(+47e)HP E-CVT    2017
# 3  FORD   FUSION         HIBRIDO 4PTAS 2.0L 4CIL 188HP AUT eCVT    2018
# 4  FORD   FUSION                HYBRID 4PTS 2.5L 4CIL 156HP CVT    2011
#
#   Trans.     Comb.  Cilindros  Potencia (HP)  Tamaño (L)        Categoría  \
# 0    CVT  Gasolina          4            188         2.0  AUTOS COMPACTOS
# 1    CVT  Gasolina          4            188         2.0  AUTOS COMPACTOS
# 2    CVT  Gasolina          4            188         2.0  AUTOS COMPACTOS
# 3    AUT  Gasolina          4            188         2.0  AUTOS COMPACTOS
# 4    CVT  Gasolina          4            156         2.5  AUTOS COMPACTOS
#
#    R. Ciudad (km/l)  R. Carr. (km/l)  R. Comb. (km/l)  R. Ajust. (km/l)  \
# ...

# %%
#Nos muestra nuestros ultimos datos, donde vemos que predomina el MERCEDES
data.tail()
# Out:
#            Marca     Submarca                                     Versión  \
# 4612  LAND ROVER  RANGE ROVER            SUPERCARGADA 5PTS 5.0L 506HP AUT
# 4613  LAND ROVER  RANGE ROVER       SUPERCARGADA 5PTS 5.0L 8CIL 506HP AUT
# 4614    MERCEDES         G 65  AMG 4X4 5PTAS 6.0L 12CIL 630HP AUT BITURBO
# 4615    MERCEDES         G 65      AMG 5PTAS 6.0L 12CIL 630HP BITURBO AUT
# 4616    MERCEDES     ML63 AMG                    5PTS 6.2L 8CIL 503HP AUT
#
#       Modelo    Trans.     Comb.  Cilindros  Potencia (HP)  Tamaño (L)  \
# 4612    2012       AUT  Gasolina          8            506        5.00
# 4613    2013       AUT  Gasolina          8            506        5.00
# 4614    2016       AUT  Gasolina         12            630        5.98
# 4615    2018       AUT  Gasolina         12            630        5.98
# 4616    2011  G TRONIC  Gasolina          8            503        6.20
#
#                              Categoría  R. Ciudad (km/l)  R. Carr. (km/l)  \
# ...

# %%
#Aqui mandamos llamar a nuestras columnas para ver si es necesario un cambio de nombre
data.columns
# Out:
# Index(['Marca', 'Submarca', 'Versión', 'Modelo', 'Trans.', 'Comb.',
#        'Cilindros', 'Potencia (HP)', 'Tamaño (L)', 'Categoría',
#        'R. Ciudad (km/l)', 'R. Carr. (km/l)', 'R. Comb. (km/l)',
#        'R. Ajust. (km/l)', 'CO2(g/km)', 'NOx (g/1000km)',
#        'Calificación Gas Ef. Inv.', 'Calificación Contam. Aire'],
#       dtype='object')

# %%
#Vemos que tres columnas tienen nombres largos por lo que cambiamos
a=data.rename(columns = {'CO2(g/km)':'emision CO2','Calificación Gas Ef. Inv.':'Calif Efecto Inv',
                             'Calificación Contam. Aire':'Calif Contam Aire','NOx (g/1000km)':'emision NOx'})

# %%
#Vemos el tipo de dato de cada columna
a.dtypes
# Out:
# Marca                 object
# Submarca              object
# Versión               object
# Modelo                 int64
# Trans.                object
# Comb.                 object
# Cilindros              int64
# Potencia (HP)          int64
# Tamaño (L)           float64
# Categoría             object
# R. Ciudad (km/l)     float64
# R. Carr. (km/l)      float64
# R. Comb. (km/l)      float64
# R. Ajust. (km/l)     float64
# emision CO2            int64
# emision NOx            int64
# Calif Efecto Inv       int64
# Calif Contam Aire     object
# dtype: object

# %%
 #Valores Nulos por columna
a.isnull().any()
# Out:
# Marca                False
# Submarca             False
# Versión              False
# Modelo               False
# Trans.                True
# Comb.                False
# Cilindros            False
# Potencia (HP)        False
# Tamaño (L)           False
# Categoría            False
# R. Ciudad (km/l)     False
# R. Carr. (km/l)      False
# R. Comb. (km/l)      False
# R. Ajust. (km/l)     False
# emision CO2          False
# emision NOx          False
# Calif Efecto Inv     False
# Calif Contam Aire    False
# dtype: bool

# %%
#Como una columna tiene datos nulos, contamos
a.isnull().sum()
# Out:
# Marca                 0
# Submarca              0
# Versión               0
# Modelo                0
# Trans.               16
# Comb.                 0
# Cilindros             0
# Potencia (HP)         0
# Tamaño (L)            0
# Categoría             0
# R. Ciudad (km/l)      0
# R. Carr. (km/l)       0
# R. Comb. (km/l)       0
# R. Ajust. (km/l)      0
# emision CO2           0
# emision NOx           0
# Calif Efecto Inv      0
# Calif Contam Aire     0
# dtype: int64

# %%
#Llenamos nuestros espacios nulos con ceros
c=a_0 =a.fillna(0)

# %%
 #Verificamos que ya no tengamos valores Nulos por columna
c.isnull().any()
# Out:
# Marca                False
# Submarca             False
# Versión              False
# Modelo               False
# Trans.               False
# Comb.                False
# Cilindros            False
# Potencia (HP)        False
# Tamaño (L)           False
# Categoría            False
# R. Ciudad (km/l)     False
# R. Carr. (km/l)      False
# R. Comb. (km/l)      False
# R. Ajust. (km/l)     False
# emision CO2          False
# emision NOx          False
# Calif Efecto Inv     False
# Calif Contam Aire    False
# dtype: bool

# %%
#Mandamos llamar nuestra base con los cambios realizados
c
# Out:
#            Marca     Submarca                                        Versión  \
# 0           FORD       FUSION         HIBRIDO 4PTS 2.0L 4CIL 188HP AUT (CVT)
# 1           FORD       FUSION        HIBRIDO 4PTS 2.0L 4CIL 188HP AUT (eCVT)
# 2           FORD       FUSION  HIBRIDO 4X2 4PTAS 2.0L 4CIL 141(+47e)HP E-CVT
# 3           FORD       FUSION         HIBRIDO 4PTAS 2.0L 4CIL 188HP AUT eCVT
# 4           FORD       FUSION                HYBRID 4PTS 2.5L 4CIL 156HP CVT
# ...          ...          ...                                            ...
# 4612  LAND ROVER  RANGE ROVER               SUPERCARGADA 5PTS 5.0L 506HP AUT
# 4613  LAND ROVER  RANGE ROVER          SUPERCARGADA 5PTS 5.0L 8CIL 506HP AUT
# 4614    MERCEDES         G 65     AMG 4X4 5PTAS 6.0L 12CIL 630HP AUT BITURBO
# 4615    MERCEDES         G 65         AMG 5PTAS 6.0L 12CIL 630HP BITURBO AUT
# 4616    MERCEDES     ML63 AMG                       5PTS 6.2L 8CIL 503HP AUT
#
# ...
