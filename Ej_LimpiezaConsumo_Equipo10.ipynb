# %% [markdown]
# # Avance del Producto Integrador de Aprendizaje
# ## Limpieza de Datos
# ### Base a trabajar: Autos - Consumo Gasolina México
# #### URL: https://www.kaggle.com/checoalejandro/autos-consumo-gasolina-mexico
#
# #### Integrantes del Equipo 10, grupo 003:
# - Andrea Isabel Cortez Sánchez 1736472
# - Sergio Oviedo Martínez 1750532
# - Andrés Hernandez de Luna 1757180

# %%
#Hacemos los llamados correspondientes para empezar a trabajar.
import pandas as pd
import numpy as np 
df_consumo = pd.read_excel("C:/Users/telmex/Documents/Consumo Gasolina Autos Ene 2018.xlsx")
df_consumo.shape #Numero de filas y columnas
# Out:
# (4617, 18)

# %%
df_consumo.head() #Vemos los primeros 5 datos de nuestras 18 columnas
# Out:
#   Marca Submarca                                        Versión  Modelo  \
# 0  FORD   FUSION         HIBRIDO 4PTS 2.0L 4CIL 188HP AUT (CVT)    2015
# 1  FORD   FUSION        HIBRIDO 4PTS 2.0L 4CIL 188HP AUT (eCVT)    2016
# 2  FORD   FUSION  HIBRIDO 4X2 4PTAS 2.0L 4CIL 141(+47e)HP E-CVT    2017
# 3  FORD   FUSION         HIBRIDO 4PTAS 2.0L 4CIL 188HP AUT eCVT    2018
# 4  FORD   FUSION                HYBRID 4PTS 2.5L 4CIL 156HP CVT    2011
#
#   Trans.     Comb.  Cilindros  Potencia (HP)  Tamaño (L)        Categoría  \
# 0    CVT  Gasolina          4            188         2.0  AUTOS COMPACTOS
# 1    CVT  Gasolina          4            188         2.0  AUTOS COMPACTOS
# 2    CVT  Gasolina          4            188         2.0  AUTOS COMPACTOS
# 3    AUT  Gasolina          4            188         2.0  AUTOS COMPACTOS
# 4    CVT  Gasolina          4            156         2.5  AUTOS COMPACTOS
#
#    R. Ciudad (km/l)  R. Carr. (km/l)  R. Comb. (km/l)  R. Ajust. (km/l)  \
# ...

# %%
df_consumo.tail() #Nos muestra nuestros ultimos datos, donde vemos que predomina el MERCEDES
# Out:
#            Marca     Submarca                                     Versión  \
# 4612  LAND ROVER  RANGE ROVER            SUPERCARGADA 5PTS 5.0L 506HP AUT
# 4613  LAND ROVER  RANGE ROVER       SUPERCARGADA 5PTS 5.0L 8CIL 506HP AUT
# 4614    MERCEDES         G 65  AMG 4X4 5PTAS 6.0L 12CIL 630HP AUT BITURBO
# 4615    MERCEDES         G 65      AMG 5PTAS 6.0L 12CIL 630HP BITURBO AUT
# 4616    MERCEDES     ML63 AMG                    5PTS 6.2L 8CIL 503HP AUT
#
#       Modelo    Trans.     Comb.  Cilindros  Potencia (HP)  Tamaño (L)  \
# 4612    2012       AUT  Gasolina          8            506        5.00
# 4613    2013       AUT  Gasolina          8            506        5.00
# 4614    2016       AUT  Gasolina         12            630        5.98
# 4615    2018       AUT  Gasolina         12            630        5.98
# 4616    2011  G TRONIC  Gasolina          8            503        6.20
#
#                              Categoría  R. Ciudad (km/l)  R. Carr. (km/l)  \
# ...

# %%
df_consumo.columns #Aqui mandamos llamar a nuestras columnas para ver si es necesario un cambio de nombre
# Out:
# Index(['Marca', 'Submarca', 'Versión', 'Modelo', 'Trans.', 'Comb.',
#        'Cilindros', 'Potencia (HP)', 'Tamaño (L)', 'Categoría',
#        'R. Ciudad (km/l)', 'R. Carr. (km/l)', 'R. Comb. (km/l)',
#        'R. Ajust. (km/l)', 'CO2(g/km)', 'NOx (g/1000km)',
#        'Calificación Gas Ef. Inv.', 'Calificación Contam. Aire'],
#       dtype='object')

# %%
#Vemos que tres columnas tienen nombres largos por lo que cambiamos
df_consumo.rename(columns = {'CO2(g/km)':'emision CO2','Calificación Gas Ef. Inv.':'Calif Efecto Inv',
                             'Calificación Contam. Aire':'Calif Contam Aire','NOx (g/1000km)':'emision NOx'})
# Out:
#            Marca     Submarca                                        Versión  \
# 0           FORD       FUSION         HIBRIDO 4PTS 2.0L 4CIL 188HP AUT (CVT)
# 1           FORD       FUSION        HIBRIDO 4PTS 2.0L 4CIL 188HP AUT (eCVT)
# 2           FORD       FUSION  HIBRIDO 4X2 4PTAS 2.0L 4CIL 141(+47e)HP E-CVT
# 3           FORD       FUSION         HIBRIDO 4PTAS 2.0L 4CIL 188HP AUT eCVT
# 4           FORD       FUSION                HYBRID 4PTS 2.5L 4CIL 156HP CVT
# ...          ...          ...                                            ...
# 4612  LAND ROVER  RANGE ROVER               SUPERCARGADA 5PTS 5.0L 506HP AUT
# 4613  LAND ROVER  RANGE ROVER          SUPERCARGADA 5PTS 5.0L 8CIL 506HP AUT
# 4614    MERCEDES         G 65     AMG 4X4 5PTAS 6.0L 12CIL 630HP AUT BITURBO
# 4615    MERCEDES         G 65         AMG 5PTAS 6.0L 12CIL 630HP BITURBO AUT
# 4616    MERCEDES     ML63 AMG                       5PTS 6.2L 8CIL 503HP AUT
#
# ...

# %%
df_consumo.dtypes
# Out:
# Marca                         object
# Submarca                      object
# Versión                       object
# Modelo                         int64
# Trans.                        object
# Comb.                         object
# Cilindros                      int64
# Potencia (HP)                  int64
# Tamaño (L)                   float64
# Categoría                     object
# R. Ciudad (km/l)             float64
# R. Carr. (km/l)              float64
# R. Comb. (km/l)              float64
# R. Ajust. (km/l)             float64
# CO2(g/km)                      int64
# NOx (g/1000km)                 int64
# Calificación Gas Ef. Inv.      int64
# Calificación Contam. Aire     object
# dtype: object

# %%
df_consumo.isnull() #Valores Nulos
# Out:
#       Marca  Submarca  Versión  Modelo  Trans.  Comb.  Cilindros  \
# 0     False     False    False   False   False  False      False
# 1     False     False    False   False   False  False      False
# 2     False     False    False   False   False  False      False
# 3     False     False    False   False   False  False      False
# 4     False     False    False   False   False  False      False
# ...     ...       ...      ...     ...     ...    ...        ...
# 4612  False     False    False   False   False  False      False
# 4613  False     False    False   False   False  False      False
# 4614  False     False    False   False   False  False      False
# 4615  False     False    False   False   False  False      False
# 4616  False     False    False   False   False  False      False
#
#       Potencia (HP)  Tamaño (L)  Categoría  R. Ciudad (km/l)  R. Carr. (km/l)  \
# 0             False       False      False             False            False
# ...

# %%
df_consumo.isnull().any() #Valores Nulos por columna
# Out:
# Marca                        False
# Submarca                     False
# Versión                      False
# Modelo                       False
# Trans.                        True
# Comb.                        False
# Cilindros                    False
# Potencia (HP)                False
# Tamaño (L)                   False
# Categoría                    False
# R. Ciudad (km/l)             False
# R. Carr. (km/l)              False
# R. Comb. (km/l)              False
# R. Ajust. (km/l)             False
# CO2(g/km)                    False
# NOx (g/1000km)               False
# Calificación Gas Ef. Inv.    False
# Calificación Contam. Aire    False
# dtype: bool

# %%
df_consumo['Trans.'].dtype # Tipo de dato de la columna que contiene valores nulos
# Out:
# dtype('O')

# %%
df_consumo_drop_column = df_consumo.dropna(axis=1) #Pedimos que nos quiten las columnas donde se manejan datos nulos

# %%
df_consumo_drop_column #Visualizamos nuestra base
# Out:
#            Marca     Submarca                                        Versión  \
# 0           FORD       FUSION         HIBRIDO 4PTS 2.0L 4CIL 188HP AUT (CVT)
# 1           FORD       FUSION        HIBRIDO 4PTS 2.0L 4CIL 188HP AUT (eCVT)
# 2           FORD       FUSION  HIBRIDO 4X2 4PTAS 2.0L 4CIL 141(+47e)HP E-CVT
# 3           FORD       FUSION         HIBRIDO 4PTAS 2.0L 4CIL 188HP AUT eCVT
# 4           FORD       FUSION                HYBRID 4PTS 2.5L 4CIL 156HP CVT
# ...          ...          ...                                            ...
# 4612  LAND ROVER  RANGE ROVER               SUPERCARGADA 5PTS 5.0L 506HP AUT
# 4613  LAND ROVER  RANGE ROVER          SUPERCARGADA 5PTS 5.0L 8CIL 506HP AUT
# 4614    MERCEDES         G 65     AMG 4X4 5PTAS 6.0L 12CIL 630HP AUT BITURBO
# 4615    MERCEDES         G 65         AMG 5PTAS 6.0L 12CIL 630HP BITURBO AUT
# 4616    MERCEDES     ML63 AMG                       5PTS 6.2L 8CIL 503HP AUT
#
# ...

# %%
df_consumo_drop_column.shape #Vemos que nos quito solo una columna donde tenemos datos nulos.
# Out:
# (4617, 17)
